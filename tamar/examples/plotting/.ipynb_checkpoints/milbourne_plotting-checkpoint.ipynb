# %% [markdown]
# # Plotting of magnetic observables and velocity components for Milbourne 2019 paper dataset

# %%
import numpy as np
import pandas as pd
import tamar.tools.plotting_funcs as plot
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/tervin/opt/anaconda3/envs/neid_data/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.2/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# Read in velocities from csv.

# %%
# csv file with rv components
csv_file = '/Users/tervin/csv_files/milbourne/rv_calcs.csv'

# csv file with reference data
data_csv = '/Users/tervin/csv_files/milbourne/milbourne_data.csv'

# %% [markdown]
# Get component lists.

# %%
# create pandas dataframe
component_df = pd.read_csv(csv_file)

# get column names
components = component_df.columns.values

# %% [markdown]
# Get data

# %%
# get velocities lists
v_phot = component_df.v_phot.values
# vphot_bright = component_df.vphot_bright.values
# vphot_spot = component_df.vphot_spot.values
v_conv = component_df.v_conv.values
rv_model = component_df.rv_model.values

# get magnetic observables
f = component_df.f.values
Bobs = component_df.Bobs.values
f_bright = component_df.f_bright.values
f_spot = component_df.f_spot.values

# %% [markdown]
# Get dates.

# %%
# get dates list
dates = component_df.date_obs.values
date_jd = component_df.date_jd.values
all_days = range(0, len(dates))

# get range based on good indices
days_range = range(0, len(Bobs))
# print(len(date_jd))

# %% [markdown]
# Get data lists.

# %%
# create pandas dataframe
ref_df = pd.read_csv(data_csv)

# get column names
ref_components = ref_df.columns.values

# %% [markdown]
# Get data only from matching dates.

# %%
data_dates =  ref_df.date_obs.values
have_dates = np.isin(data_dates, date_jd)
use_data_inds = data_dates[have_dates]
print(len(have_dates))
# Out:
# 151

# %%
# get velocities lists
v_phot_ref = ref_df.v_phot.values[have_dates]
v_conv_ref = ref_df.v_conv.values[have_dates]

# get magnetic observables
f_ref = ref_df.f.values[have_dates]
logRhk_ref = ref_df.logRhk.values[have_dates]
f_bright_ref = ref_df.f_bright.values[have_dates]
f_spot_ref = ref_df.f_spot.values[have_dates]

# get radial velocities
rv_sun = ref_df.rv_sun.values[have_dates]
rv_model_ref_calc = ref_df.rv_model_calc.values[have_dates]
rv_model_ref = ref_df.rv_model.values[have_dates]

# %% [markdown]
# Plot relevant observables for comparison.

# %%
# don't save figures currently
save_fig = None

# %% [markdown]
# Plot convective velocity.

# %%
x = date_jd
y = v_conv
title= 'Convective Velocity over Time'
xlabel = 'JD Date'
ylabel = 'Convective Velocity (m/s)'

plot.plot_timeseries(x, y, title, xlabel, ylabel, save_fig=None)

# %% [markdown]
# Plot photometric velocity.

# %%
x = date_jd
y = v_phot
title= 'Photometric Velocity over Time'
xlabel = 'JD Date'
ylabel = 'Photometric Velocity (m/s)'

plot.plot_timeseries(x, y, title, xlabel, ylabel, save_fig=None)

# %% [markdown]
# Comparison plot of magnetic observables.

# %%
x = date_jd
y_list = [f, Bobs]
xlabel = 'JD Date'
ylabel_list = ['Filling Factor (%)', 'Unsigned Flux (G)']
title = 'Comparison between Unsigned Flux and Filling Factor'
save_fig = '/Users/tervin/images/milbourne/timeseries_calc_f_calc_bobs.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# Correlation plot between unsigned flux and filling factor.

# %%
x = f
y = Bobs
xlabel = 'Filling Factor (%)'
ylabel = 'Unsigned Flux (G)'
title = 'Correlation between Unsigned Flux and Filling Factor'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_calc_f_calc_bobs.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# Correlation plot between observables and convective velocity.

# %%
x_list = [f, Bobs]
y = v_conv
title = 'Correlation between observables and convective velocity'
xlabel_list = ['Filling Factor (%)', 'Observed Unsigned Flux (%)']
ylabel = 'Convective Velocity'

plot.two_correlation_plots(x_list, y, title, xlabel_list, ylabel, save_fig=None)

# %% [markdown]
# Comparison between magnetic flux and calculated radial velocity.

# %%
x = date_jd
y_list = [Bobs, rv_model]
xlabel = 'JD Date'
ylabel_list = ['$B_{obs}\/(G)$', '$rv_{model}\/(m/s)$']
title = 'Comparison between $B_{obs}$ and Calculated $rv_{model}$'
save_fig = '/Users/tervin/images/milbourne/timeseries_calc_rvmodel_calc_Bobs.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# # Velocities Comparison

# %%
x = date_jd
y_list = [v_conv, v_phot, rv_sun, rv_model]
xlabel = 'JD Date'
ylabel_list = ['$v_{conv} \/(m/s)$','$v_{phot} \/(m/s)$', '$rv_{sun} \/(m/s)$', '$rv_{model} \/(m/s)$']
title = 'Comparison between Velocities for Milbourne 2019 Dataset'
save_fig = '/Users/tervin/images/milbourne/timeseries_vel.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)
save_fig = None

# %% [markdown]
# ## Comparison between model RV and observables

# %%
x_list = [f, Bobs]
y = rv_model
title = 'Correlation between model RV and observables'
xlabel_list = ['Filling Factor (%)', 'Unsigned Flux (G)']
ylabel = 'Model RV Variation'
save_fig = '/Users/tervin/images/milbourne/correlation_rvmodel_f_Bobs.png'

plot.two_correlation_plots(x_list, y, title, xlabel_list, ylabel, save_fig)

# %% [markdown]
# ## Plot with reference data

# %% [markdown]
# Removing the awful outlier in the reference RV.

# %%
x = date_jd
y_list = [rv_sun, rv_model_ref_calc]
xlabel = 'JD Date'
ylabel_list = ['HARPS RV', 'RV Calc Scaling']
title = 'Comparison between HARPS RV and Scaled Ref RV Variation before outlier removal'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rvscal_rv.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-299-df96fff251e2> in <module>
#       6 # save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rvscal_rv.png'
#       7
# ----> 8 plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)
#       9
#
# ~/NEID_Solar_analysis/tamar/tools/plotting_funcs.py in vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)
#     196
#     197     # plot data
# --> 198     axs[0].scatter(x, y_list[0], color='lightcoral', edgecolors='k', linewidths=1.0)
#     199     axs[1].scatter(x, y_list[1], color='lightblue', edgecolors='k', linewidths=1.0)
#     200
#
# ~/opt/anaconda3/envs/neid_data/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
# max_ind = np.argmax(rv_sun)
# rv_sun[max_ind] = (rv_sun[max_ind-1] + rv_sun[max_ind+1])/2

# %% [markdown]
# ### Compare RV variations: my coefficients, HARPS RVs.

# %%
x = date_jd
y_list = [rv_sun, rv_model_ref_calc]
xlabel = 'JD Date'
ylabel_list = ['HARPS RV', 'Scaled RV Variation']
title = 'Comparison between HARPS RV and Scaled Ref RV after outlier removal'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rv_rvscal.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# ### Comparison between HARPS RV variation and Model RV Variation.

# %%
x = date_jd
y_list = [rv_sun, rv_model_ref]
xlabel = 'JD Date'
ylabel_list = ['HARPS RV', 'Ref Model RV Variation']
title = 'Comparison between HARPS RV and Model RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rv_rvmodel.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# Comparison between modeled RV variations and actual.

# %%
x_list = [rv_model_ref, rv_model_ref_calc]
y = rv_sun
title = 'Correlation between model and scaled RV with HARPS RV'
xlabel_list = ['Ref Model RV Variation', 'Scaled RV Variation']
ylabel = 'HARPS RV Variations'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_rvs.png'

plot.two_correlation_plots(x_list, y, title, xlabel_list, ylabel, save_fig)

# %% [markdown]
# ### Compare RV model variations: my coefficients vs. theirs.

# %%
x = date_jd
y_list = [rv_model_ref, rv_model_ref_calc]
xlabel = 'JD Date'
ylabel_list = ['Ref Model RV Variation', 'Scaled RV Variation']
title = 'Comparison between Scaled Ref RV and Model RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rvscal_rvmodel.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %%
x = rv_model_ref
y = rv_model_ref_calc
xlabel = 'Ref Model RV Variation'
ylabel = 'Scaled RV Variation'
title = 'Correlation between Model RV and Scaled Model RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_rvscal_rvmodel.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# ### Comparison plots with reference convective velocity and RV variation.
# *Note: not related to my calcs just curious*

# %%
x = date_jd
y_list = [v_conv_ref, rv_sun]
xlabel = 'JD Date'
ylabel_list = ['Ref Convective Velocity', 'HARPS RV']
title = 'Comparison between Reference Convective Velocity and RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_vconv_rv.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# Correlation plot for convective velocity and rv variation for reference data.
# *Note: not related to my calcs just curious*

# %%
x = v_conv_ref
y = rv_sun
xlabel = 'Ref Convective Velocity'
ylabel = 'HARPS RV'
title = 'Correlation between Reference Convective Velocity and RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_vconv_rv.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# # Correlation between reference and calculated velocities

# %%
x_list = [v_conv, v_phot, rv_model]
y_list = [v_conv_ref, v_phot_ref, rv_model_ref]
xlabel_list = ['$v_{conv} \/(m/s)$', '$v_{phot} \/(m/s)$', '$rv_{model} \/(m/s)$']
ylabel_list = ['Ref $v_{conv} \/(m/s)$', 'Ref $v_{phot} \/(m/s)$', 'Ref $rv_{model} \/(m/s)$']
title = 'Comparison between reference and calculated velocities'
save_fig = '/Users/tervin/images/milbourne/comp_ref_calc_vels.png'

from scipy import stats
import matplotlib.pyplot as plt
# calculate correlation coefficient
corr_one = stats.spearmanr(x_list[0], y_list[0])
corr_two = stats.spearmanr(x_list[1], y_list[1])
corr_three = stats.spearmanr(x_list[2], y_list[2])

# setup the plot
fig, axs = plt.subplots(1, 3, figsize=[16, 6], gridspec_kw={'wspace': 0.2})
fig.suptitle(title)
axs[0].set(xlabel=xlabel_list[0], ylabel=ylabel_list[0])
axs[1].set(xlabel=xlabel_list[1], ylabel=ylabel_list[1])
axs[2].set(xlabel=xlabel_list[2], ylabel=ylabel_list[2])

# plot data
axs[0].scatter(x_list[0], y_list[0], color='violet', edgecolors='k', linewidths=1.0)
axs[1].scatter(x_list[1], y_list[1], color='violet', edgecolors='k', linewidths=1.0)
axs[2].scatter(x_list[2], y_list[2], color='violet', edgecolors='k', linewidths=1.0)

# label correlation coefficients
axs[0].text(0.1, 0.95, str(np.around(corr_one[0], 2)), horizontalalignment='left',
            verticalalignment='top', transform=axs[0].transAxes, weight='bold')
axs[1].text(0.1, 0.95, str(np.around(corr_two[0], 2)), horizontalalignment='left',
            verticalalignment='top', transform=axs[1].transAxes, weight='bold')
axs[2].text(0.1, 0.95, str(np.around(corr_three[0], 2)), horizontalalignment='left',
            verticalalignment='top', transform=axs[2].transAxes, weight='bold')

# remove tick marks
for ax in axs:
    ax.tick_params(labelbottom=True)

# save if needed
if save_fig is not None:
    plt.savefig(save_fig)

# %% [markdown]
# Comparison plots with reference and calculated photometric velocities.

# %%
x = date_jd
y_list = [v_phot, v_phot_ref]
xlabel = 'JD Date'
ylabel_list = ['Photometric Velocity', 'Ref Photometric Velocity']
title = 'Comparison between Reference and Calculated Photometric Velocity'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_calc_vphot.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# Correlation plot for photometric velocity.

# %%
x = v_phot
y = v_phot_ref
xlabel = 'Photometric Velocity'
ylabel = 'Reference Photometric Velocity'
title = 'Correlation between reference and calculated photometric velocity'
save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_calc_vphot.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %%
# x = vphot_spot
# y = vphot_bright
# xlabel = '$v_{phot, spot}$'
# ylabel = '$v_{phot, bright}$'
# title = 'Rotational Doppler Imbalances from Sunspots and Faculae'
# # save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_vphot_int.png'
# save_fig = None
# plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# Comparison plots with reference and calculated convective velocities.

# %%
x = date_jd
y_list = [v_conv, v_conv_ref]
xlabel = 'JD Date'
ylabel_list = ['Convective Velocity', 'Ref Convective Velocity']
title = 'Comparison between Reference and Calculated Convective Velocity'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_calc_vconv.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# Correlation plot for convective velocity.

# %%
x = v_conv
y = v_conv_ref
xlabel = 'Convective Velocity'
ylabel = 'Reference Convective Velocity'
title = 'Correlation between reference and calculated convective velocity'
save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_calc_vconv.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# Correlation plot between observables and reference convective velocity.

# %%
x_list = [f, Bobs]
y = v_conv_ref
title = 'Correlation between observables and reference convective velocity'
xlabel_list = ['Filling Factor (%)', 'Observed Unsigned Flux (G)']
ylabel = 'Ref Convective Velocity'
save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_vconv_calc_mag.png'

plot.two_correlation_plots(x_list, y, title, xlabel_list, ylabel, save_fig)

# %% [markdown]
# Comparison plots with reference magnetic observables.

# %%
x = date_jd
y_list = [Bobs, f, f_ref]
xlabel = 'JD Date'
ylabel_list = ['$B_{obs}\/ (G)$', '$f$ (%)', 'Ref $f$ (%)']
title = 'Comparison between Reference and Calculated Magnetic Observables'
save_fig = '/Users/tervin/images/milbourne/timeseries_ref_calc_mag.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %%
x = date_jd
y_list = [Bobs, rv_sun, rv_model]
xlabel = 'JD Date'
ylabel_list = ['$B_{obs}\/ (G)$', '$rv_{model}\/ (m/s)$', '$rv_{sun}\/ (m/s)$']
title = 'Comparison between Unsigned Flux and Velocities'
save_fig = '/Users/tervin/images/milbourne/timeseries_calc_Bobs_rvsun_rvmodel.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list)

# %%
x = f
y = f_ref
xlabel = 'Filling Factor (%)'
ylabel = 'Ref Filling Factor (%)'
title = 'Correlation between Reference and Calculated filling factor'
save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_calc_f.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# Compare reference RVs to filling factor.

# %%
x = date_jd
y_list = [f, rv_sun]
xlabel = 'JD Date'
ylabel_list = ['Filling Factor (%)', 'HARPS RV Variation']
title = 'Comparison between Filling Factor and HARPS RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rv_calc_f.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %%
x = y_list[0]
y = y_list[1]
xlabel = 'Filling Factor (%)'
ylabel = 'Reference RV Variation'
title = 'Correlation between Filling Factor and Reference RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_rv_calc_f.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# Compare reference RVs to unsigned flux.

# %%
x = date_jd
y_list = [Bobs, rv_sun]
xlabel = 'JD Date'
ylabel_list = ['Unsigned Flux (G)', 'Reference RV Variation']
title = 'Comparison between Unsigned Flux and Reference RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rv_calc_bobs.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %%
x = y_list[0]
y = y_list[1]
xlabel = 'Unsigned Flux (G)'
ylabel = 'Reference RV Variation'
title = 'Correlation between Unsigned Flux and Reference RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_rv_calc_bobs.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# # Subtract unsigned flux

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
X = Bobs.reshape(-1, 1)
Y = rv_sun
reg = LinearRegression(positive=True).fit(X, Y)
m, b = reg.coef_, reg.intercept_

fit_line = m*Bobs + b
rv_Bobs = rv_sun - fit_line

print('Edited RV STD:', np.std(rv_Bobs))
print('NEID RV STD:', np.std(rv_sun))

# %%
plt.scatter(Bobs, rv_sun, color='orchid', edgecolor='k', linewidths=1.0)
plt.plot(Bobs, fit_line, color='lightpink')
plt.xlabel('NEID RV')
plt.ylabel('$B_{obs}$')
plt.title('Comparison of $B_{obs}$ and NEID RV')

# %%
x = date_jd
y_list = [rv_Bobs, rv_sun]
xlabel = 'JD Date'
ylabel_list = ['Edited RV', 'HARPS RV']
title = 'Comparison between edited RV and HARPS RV'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_calc_f_ref_logrhk.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %%
x_list = [rv_model, rv_sun]
y = rv_Bobs
title = 'Correlation between edited RVs'
xlabel_list = ['Model RV', 'NEID RV']
ylabel = 'Edited RV'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_calc_f_calc_fbright_ref_logrhk.png'

plot.two_correlation_plots(x_list, y, title, xlabel_list, ylabel, save_fig)

# %% [markdown]
# # Compare LogRhk reference value to filling factor.

# %%
x = date_jd
y_list = [f, logRhk_ref]
xlabel = 'JD Date'
ylabel_list = ['Filling Factor (%)', '$logR\'_{HK}$']
title = 'Comparison between $f$ and $logR\'_{HK}$'
save_fig = '/Users/tervin/images/milbourne/timeseries_calc_f_ref_logrhk.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %%
x = f
y = logRhk_ref
xlabel = 'Ref Filling Factor (%)'
ylabel = '$logR\'_{HK}$'
title = 'Correlation between reference $f$ and $logR\'_{HK}$'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_f_ref_logrhk.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig=None)

# %%
x_list = [f_spot, f_bright]
y = logRhk_ref
title = 'Correlation between filling factor and $logR\'_{HK}$'
xlabel_list = ['$f_{spot}$ (%)', '$f_{bright}}$ (%)']
ylabel = '$logR\'_{HK}$'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_calc_f_calc_fbright_ref_logrhk.png'


plot.two_correlation_plots(x_list, y, title, xlabel_list, ylabel, save_fig)

# %%
x = date_jd
y_list = [f, f_bright, f_spot, logRhk_ref]
xlabel = 'JD Date'
ylabel_list = ['$f$ (%)', '$f_{bright}$ (%)', '$f_{spot}$ (%)', '$logR\'_{HK}$']
title = 'Comparison between filling factors and $logR\'_{HK}$'
save_fig = '/Users/tervin/images/milbourne/timeseries_calc_f_ref_logrhk.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# # Compare model and reference RVs.

# %%
x = date_jd
y_list = [rv_model, rv_sun]
xlabel = 'JD Date'
ylabel_list = ['Model RV Variation', 'HARPS RV Variation']
title = 'Comparison between Model and Reference RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rv_calc_rv.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %%
x = rv_model
y = rv_sun
xlabel = 'Model RV Variation'
ylabel = 'HARPS RV'
title = 'Correlation between Calculated and HARPS RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_rv_calc_rv.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %%
x = rv_model
y = rv_model_ref
xlabel = 'Model RV Variation'
ylabel = 'Ref Model RV Variation'
title = 'Correlation between Model RV and Ref RV Variation'
save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_rvmodel_calc_rv.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %%
x = rv_model
y = rv_model_ref_calc
xlabel = 'Model RV Variation'
ylabel = 'Ref Model RV Scaled Variation'
title = 'Correlation between Model RV and Ref Calc RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_rvscal_calc_rv.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)
