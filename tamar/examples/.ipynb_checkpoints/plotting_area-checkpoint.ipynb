# %% [markdown]
# # Creation of active region area plots
#
# Based on Figure 6 from Milbourne 2016.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# csv file with rv components
csv_file = '/Users/tervin/csv_files/milbourne/area_plot.csv'
df = pd.read_csv(csv_file)

# %%
dates = df.date_obs.values
co_lat = np.sin(df.co_lat.values)
area = df.area.values
# area = np.where(area>20000, 20000, area)

obs = len(np.unique(dates))
print("Number of observations: " + str(obs))
# Out:
# Number of observations: 30

# %% [markdown]
# Get area in microhemisphere ($\mu Hem$).
# This is $10^{-6}$ of half the Sun.

# %%
uHem = 150e3
area_hem = area / uHem

# %% [markdown]
# Get the fraction of active regions for the colormap.
# Not sure this is correct.

# %%
total = co_lat*area/np.sum(area)

# %%
x = area
y = co_lat
c = total
# xlabel = 'Area ($\mu Hem$)'
xlabel = 'Pixel Area'
ylabel = '$sin \Theta$'
title = 'Comparison of active regions as function of area and latitude'

plt.scatter(x, y, c=c)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.ylim(0.1, 1.1)
plt.colorbar()
plt.show()

# %%
large_area = np.where(area>10000)
print(len(large_area[0]))
print(large_area)
small_areas = area
small_areas = np.where(small_areas > 10000, 10000, small_areas)
# Out:
# 82
# (array([  455,   457,  2034,  2214,  2944,  3005,  3834,  3950,  4029,
#         4120,  4664,  4688,  5665,  5666,  5812,  6404,  6425,  7420,
#         7518,  7656,  7760,  7826,  8228,  9256,  9352,  9380,  9470,
#         9690, 11174, 11236, 11283, 11321, 11379, 11596, 13140, 13201,
#        13232, 13360, 15103, 15170, 15187, 15275, 15461, 16105, 17024,
#        17101, 17974, 18987, 19090, 19897, 19929, 21757, 23525, 25212,
#        26904, 28488, 28503, 30066, 30134, 31683, 31761, 33297, 33399,
#        35067, 36696, 38333, 40055, 41891, 42198, 43676, 44032, 45538,
#        47229, 47739, 48683, 49659, 49768, 50992, 51425, 51475, 53247,
#        53358]),)

# %%
x = small_areas
y = co_lat
c = total
# xlabel = 'Area ($\mu Hem$)'
xlabel = 'Pixel Area'
ylabel = '$sin \Theta$'
title = 'Comparison of active regions as function of area and latitude'

plt.scatter(x, y, c=c)
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(title)
plt.ylim(0.1, 1.1)
plt.colorbar()
plt.show()
