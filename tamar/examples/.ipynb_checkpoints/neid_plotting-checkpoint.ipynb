# %% [markdown]
# # Plotting stuff from NEID calcluations and data

# %%
import numpy as np
import pandas as pd
import tamar.tools.plotting_funcs as plot

# %% [markdown]
# Read in velocities from csv.

# %%
# csv file with rv components
csv_file = '/Users/tervin/csv_files/neid/solar_rot.csv'

# %% [markdown]
# Get component lists.

# %%
# create pandas dataframe
component_df = pd.read_csv(csv_file)

# get column names
components = component_df.columns.values
print(components)
# Out:
# ['date_obs' 'jd_date' 'rv_sun' 'v_quiet' 'v_disc' 'v_phot' 'v_conv'
#  'f_bright' 'f_spot' 'f' 'Bobs' 'rv_model']

# %% [markdown]
# Ensure that the lists are valid.

# %%
# # get list to check for bad indices
# v_phot = component_df.v_phot.values

# # get bad indices
# bad_inds = np.where(np.isnan((v_phot)))
# good_inds = np.isin(range(0, len(v_phot)), bad_inds[0], invert=True)

# %%
# # get velocities lists
# v_phot = component_df.v_phot.values[good_inds]
# v_conv = component_df.v_conv.values[good_inds]

# # get magnetic observables
# f = component_df.f.values[good_inds]
# Bobs = component_df.Bobs.values[good_inds]

# # get radial velocities
# rv_sun = component_df.rv_sun.values[good_inds]

# %%
# get velocities lists
v_phot = component_df.v_phot.values
v_conv = component_df.v_conv.values
rv_sun = component_df.rv_sun.values
rv_model = component_df.rv_model.values

# get magnetic observables
f = component_df.f.values
Bobs = component_df.Bobs.values
f_bright = component_df.f_bright.values
f_spot = component_df.f_spot.values

# %%
import matplotlib.pyplot as plt
# plt.plot(rv_sun)

# %%
rv_sun = rv_sun * 1000 
plt.scatter(range(0, len(rv_sun)), rv_sun)

# %% [markdown]
# Get dates.

# %%
# # get dates list
# dates = component_df.date_obs.values[good_inds]
# days_range = range(0, len(dates))

# %%
# get dates list
dates = component_df.date_obs.values
jan_11_ind = np.where(dates != '2021-01-11T12:00:00.00')

# %%
# don't save figures for now
save_fig = None

# %%
# remove jan 11, 2021
dates = dates[jan_11_ind[0]]
f = f[jan_11_ind[0]]
Bobs = Bobs[jan_11_ind[0]]
rv_sun = rv_sun[jan_11_ind[0]]
rv_model = rv_model[jan_11_ind[0]]
days_range = range(0, len(dates))

# %%
## Magnetic Observable Comparisons

# %% [markdown]
# Comparison plot of magnetic observables.

# %%
x = days_range
y_list = [f, Bobs]
xlabel = ['Observations']
ylabel_list = ['Filling Factor (%)', 'Unsigned Flux (G)']
title = 'Comparison between Unsigned Flux and Filling Factor'
# save_fig = '/Users/tervin/images/neid/area_constraint/timeseries_calc_f_calc_bobs.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# Remove the three outliers.

# %%
# bad_inds = np.where(f > 10)

# # update filling factor
# new_f = (f[bad_inds[0][0] - 1] + f[bad_inds[-1][-1] + 1])/2
# f[bad_inds] = new_f

# # update unsigned flux
# new_B = (Bobs[bad_inds[0][0] - 1] + Bobs[bad_inds[-1][-1] + 1])/2
# Bobs[bad_inds] = new_B

# %% [markdown]
# Determine the dates of these outliers.

# %%
# bad_dates = dates[bad_inds]
# print(bad_dates)

# %% [markdown]
# Comparison plot of magnetic observables after removal.

# %%
# x = days_range
# y_list = [f, Bobs]
# xlabel = ['Observations']
# ylabel_list = ['Filling Factor (%)', 'Unsigned Flux (G)']
# title = 'Comparison between Unsigned Flux and Filling Factor after outlier removal'
# # # save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_calc_f_calc_bobs.png'

# plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %% [markdown]
# Correlation plot between unsigned flux and filling factor.

# %%
x = f
y = Bobs
xlabel = 'Filling Factor (%)'
ylabel = 'Unsigned Flux (G)'
title = 'Correlation between Unsigned Flux and Filling Factor'
# # save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_calc_f_calc_bobs.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# ## Filling Factor and NEID RV Comparison

# %% [markdown]
# Compare NEID RVs to filling factor.

# %%
x = days_range
y_list = [f, rv_sun]
xlabel = ['Observations']
ylabel_list = ['Filling Factor (%)', 'NEID RV Variation']
title = 'Comparison between Filling Factor and NEID RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rv_calc_f.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %%
x = f
y = rv_sun
xlabel = 'Filling Factor (%)'
ylabel = 'NEID RV Variation'
title = 'Correlation between Filling Factor and NEID RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_rv_calc_f.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# ## Compare NEID RVs to unsigned flux.

# %% [markdown]
# Compare NEID RVs to unsigned flux.

# %%
x = days_range
y_list = [Bobs, rv_sun]
xlabel = ['Observations']
ylabel_list = ['Unsigned Flux (G)', 'NEID RV Variation']
title = 'Comparison between Unsigned Flux and NEID RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/timeseries_ref_rv_calc_bobs.png'

plot.vert_comp_timeseries(x, y_list, title, xlabel, ylabel_list, save_fig)

# %%
x = Bobs
y = rv_sun
xlabel = 'Unsigned Flux (G)'
ylabel = 'NEID RV Variation'
title = 'Correlation between Unsigned Flux and NEID RV Variation'
# save_fig = '/Users/tervin/images/milbourne_ref/area_constraint/correlation_ref_rv_calc_bobs.png'

plot.correlation_plot(x, y, title, xlabel, ylabel, save_fig)

# %% [markdown]
# ## Comparison with model RV variation
